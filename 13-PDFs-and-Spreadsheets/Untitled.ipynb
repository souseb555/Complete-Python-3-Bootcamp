# %%
import csv

read_file=open("example.csv", encoding='utf-8')
csv_data=csv.reader(read_file)
data_line=list(csv_data)

# %%
print(data_line)
# Out:
# [['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city'], ['1', 'Joseph', 'Zaniolini', 'jzaniolini0@simplemachines.org', 'Male', '163.168.68.132', 'Pedro Leopoldo'], ['2', 'Freida', 'Drillingcourt', 'fdrillingcourt1@umich.edu', 'Female', '97.212.102.79', 'Buri'], ['3', 'Nanni', 'Herity', 'nherity2@statcounter.com', 'Female', '145.151.178.98', 'Claver'], ['4', 'Orazio', 'Frayling', 'ofrayling3@economist.com', 'Male', '25.199.143.143', 'Kungur'], ['5', 'Julianne', 'Murrison', 'jmurrison4@cbslocal.com', 'Female', '10.186.243.144', 'Sainte-Luce-sur-Loire'], ['6', 'Lucy', 'Gamet', 'lgamet5@list-manage.com', 'Female', '10.151.93.36', 'Pak Phli'], ['7', 'Dyana', 'Howatt', 'dhowatt6@amazon.com', 'Female', '224.169.61.29', 'Palmares'], ['8', 'Kassey', 'Herion', 'kherion7@amazon.com', 'Female', '245.51.154.79', 'Zákynthos'], ['9', 'Chrissy', 'Hedworth', 'chedworth8@china.com.cn', 'Male', '124.222.93.57', 'Boevange-sur-Attert'], ['10', 'Hyatt', 'Gasquoine', 'hgasquoine9@googl
# ...

# %%
data_line[0]
# Out:
# ['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city']

# %%
data_line[0:]
# Out:
# [['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city'],
#  ['1',
#   'Joseph',
#   'Zaniolini',
#   'jzaniolini0@simplemachines.org',
#   'Male',
#   '163.168.68.132',
#   'Pedro Leopoldo'],
#  ['2',
#   'Freida',
#   'Drillingcourt',
#   'fdrillingcourt1@umich.edu',
#   'Female',
#   '97.212.102.79',
#   'Buri'],
#  ['3',
#   'Nanni',
#   'Herity',
#   'nherity2@statcounter.com',
#   'Female',
#   '145.151.178.98',
#   'Claver'],
#  ['4',
#   'Orazio',
#   'Frayling',
#   'ofrayling3@economist.com',
#   'Male',
#   '25.199.143.143',
#   'Kungur'],
#  ['5',
#   'Julianne',
#   'Murrison',
#   'jmurrison4@cbslocal.com',
#   'Female',
#   '10.186.243.144',
#   'Sainte-Luce-sur-Loire'],
#  ['6',
#   'Lucy',
#   'Gamet',
#   'lgamet5@list-manage.com',
#   'Female',
#   '10.151.93.36',
#   'Pak Phli'],
#  ['7',
#   'Dyana',
#   'Howatt',
#   'dhowatt6@amazon.com',
#   'Female',
#   '224.169.61.29',
#   'Palmares'],
#  ['8',
#   'Kassey',
#   'Herion',
# ...

# %%
data_line[:3]
# Out:
# [['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city'],
#  ['1',
#   'Joseph',
#   'Zaniolini',
#   'jzaniolini0@simplemachines.org',
#   'Male',
#   '163.168.68.132',
#   'Pedro Leopoldo'],
#  ['2',
#   'Freida',
#   'Drillingcourt',
#   'fdrillingcourt1@umich.edu',
#   'Female',
#   '97.212.102.79',
#   'Buri']]

# %%
for line in data_line[:5]:
    print(line)
# Out:
# ['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city']
# ['1', 'Joseph', 'Zaniolini', 'jzaniolini0@simplemachines.org', 'Male', '163.168.68.132', 'Pedro Leopoldo']
# ['2', 'Freida', 'Drillingcourt', 'fdrillingcourt1@umich.edu', 'Female', '97.212.102.79', 'Buri']
# ['3', 'Nanni', 'Herity', 'nherity2@statcounter.com', 'Female', '145.151.178.98', 'Claver']
# ['4', 'Orazio', 'Frayling', 'ofrayling3@economist.com', 'Male', '25.199.143.143', 'Kungur']

# %%
all_emails = []
for line in data_line[1:15]:
    all_emails.append(line[3])

# %%
print(all_emails)
# Out:
# ['jzaniolini0@simplemachines.org', 'fdrillingcourt1@umich.edu', 'nherity2@statcounter.com', 'ofrayling3@economist.com', 'jmurrison4@cbslocal.com', 'lgamet5@list-manage.com', 'dhowatt6@amazon.com', 'kherion7@amazon.com', 'chedworth8@china.com.cn', 'hgasquoine9@google.ru', 'ftarra@shareasale.com', 'abathb@umn.edu', 'lchastangc@goo.gl', 'cceried@yale.edu']

# %%
full_names = []

for line in data_line[1:15]:
    full_names.append(line[1]+' '+line[2])

# %%
print(full_names)
# Out:
# ['Joseph Zaniolini', 'Freida Drillingcourt', 'Nanni Herity', 'Orazio Frayling', 'Julianne Murrison', 'Lucy Gamet', 'Dyana Howatt', 'Kassey Herion', 'Chrissy Hedworth', 'Hyatt Gasquoine', 'Felicdad Tarr', 'Andrew Bath', 'Lucais Chastang', 'Car Cerie']

# %%
import csv
data = open('Exercise_Files/find_the_link.csv',encoding="utf-8")
csv_data = csv.reader(data)
data_lines = list(csv_data)
link_list = []
for row_num,data in enumerate(data_lines):
    link_list.append(data[row_num])
''.join(link_list)
data.close()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-9-2ef9ef17d0b8> in <module>
#       7     link_list.append(data[row_num])
#       8 ''.join(link_list)
# ----> 9 data.close()
#
# AttributeError: 'list' object has no attribute 'close'

# %%
import PyPDF2
f = open('Exercise_Files/find_the_link.csv','rb')
pdf_text = []
pdf_reader = PyPDF2.PdfFileReader(f)
for p in range(pdf_reader.numPages):
    
    page = pdf_reader.getPage(p)
    
    pdf_text.append(page.extractText())
pdf_text
# Out:
# ---------------------------------------------------------------------------
# PdfReadError                              Traceback (most recent call last)
# <ipython-input-8-5d2fdb542023> in <module>
#       2 f = open('Exercise_Files/find_the_link.csv','rb')
#       3 pdf_text = []
# ----> 4 pdf_reader = PyPDF2.PdfFileReader(f)
#       5 for p in range(pdf_reader.numPages):
#       6
#
# ~\Anaconda3\lib\site-packages\PyPDF2\pdf.py in __init__(self, stream, strict, warndest, overwriteWarnings)
#    1082             stream = BytesIO(b_(fileobj.read()))
#    1083             fileobj.close()
# -> 1084         self.read(stream)
#    1085         self.stream = stream
#    1086
#
# ~\Anaconda3\lib\site-packages\PyPDF2\pdf.py in read(self, stream)
#    1694         while line[:5] != b_("%%EOF"):
#    1695             if stream.tell() < last1K:
# -> 1696                 raise utils.PdfReadError("EOF marker not found")
#    1697             line = self.readNextEndLine(stream)
# ...
